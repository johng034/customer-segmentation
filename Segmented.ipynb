# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('./saved-items/labeled.pkl')

df.head()
# Out:
#    Num_children  Child  Income  Wines  Fruits  Meat  Fish  Sweets  Gold  \
# 0             0      0   58138    635      88   546   172      88    88
# 1             2      1   46344     11       1     6     2       1     6
# 2             0      0   71613    426      49   127   111      21    42
# 3             1      1   26646     11       4    20    10       3     5
# 4             1      1   58293    173      43   118    46      27    15
#
#    Total  labels
# 0   1617       1
# 1     27       0
# 2    776       1
# 3     53       0
# 4    422       0

# %%
sns.pairplot(df)
plt.show()

# %%
# Create separate DataFrames for each label
zero  = df[df['labels'] == 0].copy()
one   = df[df['labels'] == 1].copy()
two   = df[df['labels'] == 2].copy()
three = df[df['labels'] == 3].copy()

# %%
print(f"""
Number of Customers in Each Group:

High spenders, no children   (Group 2): {two.shape[0]}
High spenders, with children (Group 1): {one.shape[0]}
Low spenders, no children    (Group 3): {three.shape[0]}
Low spenders, with children  (Group 0): {zero.shape[0]}
""")
# Out:
# Number of Customers in Each Group:
#
# High spenders, no children   (Group 2): 449
# High spenders, with children (Group 1): 443
# Low spenders, no children    (Group 3): 183
# Low spenders, with children  (Group 0): 1126
